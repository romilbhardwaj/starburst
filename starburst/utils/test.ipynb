# %%
import matplotlib.pyplot as plt
import numpy as np

# Some example data to display
x = np.linspace(0, 2 * np.pi, 400)
y = np.sin(x ** 2)

n = 10
fig, axs = plt.subplots(n, figsize=(10,50))
fig.suptitle('Vertically stacked subplots')
for i in range(n):
    axs[i].plot(x * i, y * i)
